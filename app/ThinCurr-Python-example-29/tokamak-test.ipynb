# %%
import struct
import sys
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import pyvista

# plt.rcParams['figure.figsize']=(12,12)
# plt.rcParams['font.weight']='bold'
# plt.rcParams['axes.labelweight']='bold'
# plt.rcParams['lines.linewidth']=2
# plt.rcParams['lines.markeredgewidth']=2
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
from OpenFUSIONToolkit import OFT_env
from OpenFUSIONToolkit.ThinCurr import ThinCurr
# from OpenFUSIONToolkit.ThinCurr.sensor import Mirnov, save_sensors
# from OpenFUSIONToolkit.util import mu0
# from OpenFUSIONToolkit.io import histfile

# %%
hdf5_file_path = 'tokamak_mesh_EHL2_66holes.h5'
curr_file_path = 'Central_Solenoid_Current.txt'
xml_file_path  = 'oft_in.xml'

def print_h5_tree(group, indent=0):
    for key in group.keys():
        item = group[key]
        if isinstance(item, h5py.Dataset):
            print(' ' * indent + f"├── {key} (Dataset) {item.shape} {item.dtype}")
        elif isinstance(item, h5py.Group):
            print(' ' * indent + f"├── {key} (Group)")
            print_h5_tree(item, indent + 4)
with h5py.File(hdf5_file_path, 'r') as h5_file:
    print("HDF5 file tree structure:")
    print_h5_tree(h5_file)
# Out:
# HDF5 file tree structure:
# ├── mesh (Group)
#     ├── LC (Dataset) (40652, 3) int32
#     ├── NODESET0001 (Dataset) (12,) int32
#     ├── NODESET0002 (Dataset) (12,) int32
#     ├── NODESET0003 (Dataset) (12,) int32
#     ├── NODESET0004 (Dataset) (12,) int32
#     ├── NODESET0005 (Dataset) (22,) int32
#     ├── NODESET0006 (Dataset) (18,) int32
#     ├── NODESET0007 (Dataset) (22,) int32
#     ├── NODESET0008 (Dataset) (22,) int32
#     ├── NODESET0009 (Dataset) (18,) int32
#     ├── NODESET0010 (Dataset) (22,) int32
#     ├── NODESET0011 (Dataset) (12,) int32
#     ├── NODESET0012 (Dataset) (12,) int32
#     ├── NODESET0013 (Dataset) (12,) int32
#     ├── NODESET0014 (Dataset) (12,) int32
#     ├── NODESET0015 (Dataset) (22,) int32
#     ├── NODESET0016 (Dataset) (22,) int32
#     ├── NODESET0017 (Dataset) (18,) int32
#     ├── NODESET0018 (Dataset) (22,) int32
#     ├── NODESET0019 (Dataset) (22,) int32
#     ├── NODESET0020 (Dataset) (18,) int32
#     ├── NODESET0021 (Dataset) (22,) int32
#     ├── NODESET0022 (Dataset) (22,) int32
#     ├── NODESET0023 (Dataset) (22,) int32
#     ├── NODESET0024 (Dataset) (22,) int32
#     ├── NODESET0025 (Dataset) (22,) int32
#     ├── NODESET0026 (Dataset) (22,) int32
#     ├── NODESET0027 (Dataset) (22,) int32
#     ├── NODESET0028 (Dataset) (22,) int32
#     ├── NODESET0029 (Dataset) (18,) int32
#     ├── NODESET0030 (Dataset) (22,) int32
#     ├── NODESET0031 (Dataset) (22,) int32
#     ├── NODESET0032 (Dataset) (18,) int32
#     ├── NODESET0033 (Dataset) (22,) int32
#     ├── NODESET0034 (Dataset) (22,) int32
#     ├── NODESET0035 (Dataset) (6,) int32
#     ├── NODESET0036 (Dataset) (6,) int32
#     ├── NODESET0037 (Dataset) (6,) int32
#     ├── NODESET0038 (Dataset) (6,) int32
#     ├── NODESET0039 (Dataset) (6,) int32
#     ├── NODESET0040 (Dataset) (6,) int32
#     ├── NODESET0041 (Dataset) (6,) int32
#     ├── NODESET0042 (Dataset) (6,) int32
#     ├── NODESET0043 (Dataset) (12,) int32
#     ├── NODESET0044 (Dataset) (12,) int32
#     ├── NODESET0045 (Dataset) (12,) int32
#     ├── NODESET0046 (Dataset) (12,) int32
#     ├── NODESET0047 (Dataset) (22,) int32
#     ├── NODESET0048 (Dataset) (18,) int32
#     ├── NODESET0049 (Dataset) (22,) int32
#     ├── NODESET0050 (Dataset) (22,) int32
#     ├── NODESET0051 (Dataset) (18,) int32
#     ├── NODESET0052 (Dataset) (22,) int32
#     ├── NODESET0053 (Dataset) (12,) int32
#     ├── NODESET0054 (Dataset) (12,) int32
#     ├── NODESET0055 (Dataset) (12,) int32
#     ├── NODESET0056 (Dataset) (12,) int32
#     ├── NODESET0057 (Dataset) (6,) int32
#     ├── NODESET0058 (Dataset) (6,) int32
#     ├── NODESET0059 (Dataset) (6,) int32
#     ├── NODESET0060 (Dataset) (6,) int32
#     ├── NODESET0061 (Dataset) (6,) int32
#     ├── NODESET0062 (Dataset) (6,) int32
#     ├── NODESET0063 (Dataset) (6,) int32
#     ├── NODESET0064 (Dataset) (6,) int32
#     ├── NODESET0065 (Dataset) (171,) int32
#     ├── NODESET0066 (Dataset) (44,) int32
#     ├── NUM_NODESETS (Dataset) (1,) int32
#     ├── R (Dataset) (20742, 3) float64
#     ├── REG (Dataset) (40652, 1) int32

# %%
from pathlib import Path
from typing import List, Tuple
def load_time_current_txt(path: str) -> Tuple[List[float], List[float]]:
    """Load time (ms) and current (A) from a plain text file."""
    times_ms: List[float] = []
    currents_a: List[float] = []
    
    # 将字符串路径转换为 Path 对象
    path_obj = Path(path)
    with path_obj.open("r", encoding="utf-8") as f:
        for line in f:
            stripped = line.strip()
            if not stripped:
                continue
            # Skip header or comment lines
            if stripped.startswith("#") or "Time" in stripped or "Current" in stripped:
                continue

            parts = stripped.split()
            if len(parts) < 2:
                continue

            try:
                t_ms = float(parts[0])
                I_a = float(parts[1])
            except ValueError:
                # Non-numeric line, skip
                continue

            times_ms.append(t_ms)
            currents_a.append(I_a)

    if not times_ms:
        raise ValueError(f"No valid data lines found in {path}")

    return times_ms, currents_a

# %%
times_ms, currents_a = load_time_current_txt(curr_file_path)
print(np.shape(times_ms))
print(np.shape(currents_a))
# Out:
# (3301,)
# (3301,)

# %%
ax, fig = plt.subplots()
fig.plot(times_ms, currents_a)
fig.set_xlabel('Time (ms)')
fig.set_ylabel('Current (A)')
fig.set_title('Central Solenoid Current')
# Out:
# Text(0.5, 1.0, 'Central Solenoid Current')

# %%
myOFT = OFT_env(nthreads=28)
tw_torus = ThinCurr(myOFT)
tw_torus.setup_model(mesh_file=hdf5_file_path,xml_filename=xml_file_path)
tw_torus.setup_io()
# Out:
# Warning: Request of 28 threads exceeds 20 physical cores detected by OFT (excluding "efficiency" cores)
#          If correct, this may significantly degrade performance due to oversubcription
# #----------------------------------------------
# Open FUSION Toolkit Initialized
# Development branch:    yfzhao-260317-aliyun/qwen
# Revision id:           5330e86
# Parallelization Info:
#   Not compiled with MPI
#   # of OpenMP threads =   28
# Fortran input file    = /tmp/oft_1535372/oftpyin
# XML input file        = none
# Integer Precisions    =    4   8
# Float Precisions      =    4   8  10
# Complex Precisions    =    4   8
# LA backend            = native
# #----------------------------------------------
#
#
# Creating thin-wall model
#   No V(t) driver coils found
#   Loading I(t) driver coils
#     Masked      0 coils from sensors
#   Building holes
#
#   Loading region resistivity:
#      1  3.7000E-05
#      2  2.4670E-05
#      3  5.6920E-05
#      4  3.7000E-05
#
#   Setup complete:
#     # of points    =        20742
#     # of edges     =        61458
#     # of cells     =        40652
#     # of holes     =           66
#     # of closures  =            0
#     # of Vcoils    =            0
#     # of Icoils    =            1

# %%
# sensors = []
# for i, theta in enumerate(np.linspace(0.0,2.0*np.pi/20.0,3)):
#     print(i,theta*180.0/np.pi)
#     sensors.append(Mirnov(1.6*np.r_[np.cos(theta),np.sin(theta),0.0], np.r_[0.0,0.0,1.0], 'Bz_{0}'.format(i+1)))
# save_sensors(sensors)
# Msensor, Msc, sensor_obj = tw_torus.compute_Msensor('floops.loc')

# %%
Mc = tw_torus.compute_Mcoil()
# Out:
# Building coil<->element inductance matrices
#   Time =  1s

# %%
tw_torus.compute_Lmat(use_hodlr=True,cache_file='DATA_HOLDR_L.save')
# Out:
#  Partitioning grid for block low rank compressed operators
#    nBlocks =                  32
#    Avg block size =          618
#    # of SVD =                210
#    # of ACA =                166
#
#  Building block low rank inductance operator
#    Building hole and Vcoil columns
#    Building diagonal blocks
#      10%
#      20%
#      30%
#      40%
#      50%
#      60%
#      70%
#      80%
#      90%
#    Building off-diagonal blocks using ACA+
#      10%
#      20%
#      30%
#      40%
#      50%
#      60%
#      70%
#      80%
#      90%
#      Compression ratio:   8.3%  ( 3.23E+07/ 3.91E+08)
#      Time = 25s
#    Saving HODLR matrix to file: DATA_HOLDR_L.save

# %%
tw_torus.compute_Rmat()
# Out:
# Building resistivity matrix

# %%
dt = 1.E-3
nsteps = 3300
# coil_currs = np.array([
#     [0.0,   1.E6],
#     [4.E-3, 0.0],
#     [1.0,   0.0]
# ])
# coil_currs = np.array([
#     [0.0, 1.E6],
#     [8.E-3, 0.0],
#     [1.0, 0.0]
# ])

coil_currs = []

for i in range(len(currents_a)):
    coil_currs.append([1e-3 * i , currents_a[i]])
coil_currs = np.array(coil_currs)
# tw_torus.run_td(dt,nsteps,status_freq=10,coil_currs=coil_currs,sensor_obj=sensor_obj)

# %%
tw_torus.run_td(dt,nsteps,status_freq=10,plot_freq=30,coil_currs=coil_currs)
# Out:
# Starting time-domain simulation
#   timestep    time           sol_norm     nits    solver time
#       10    1.000000E-02    1.3995E-02       1        0.01
#       20    2.000000E-02    2.0106E-02       1        0.01
#       30    3.000000E-02    2.3589E-02       1        0.01
#       40    4.000000E-02    2.6022E-02       1        0.01
#       50    5.000000E-02    2.7883E-02       1        0.01
#       60    6.000000E-02    2.8541E-02       1        0.01
#       70    7.000000E-02    2.8878E-02       1        0.01
#       80    8.000000E-02    2.9145E-02       1        0.01
#       90    9.000000E-02    2.9322E-02       1        0.01
#      100    1.000000E-01    2.9399E-02       1        0.01
#      110    1.100000E-01    2.9384E-02       1        0.01
#      120    1.200000E-01    2.9292E-02       1        0.01
#      130    1.300000E-01    2.9147E-02       1        0.01
#      140    1.400000E-01    2.8970E-02       1        0.01
#      150    1.500000E-01    2.8782E-02       1        0.01
#      160    1.600000E-01    2.8598E-02       1        0.01
#      170    1.700000E-01    2.8430E-02       1        0.01
#      180    1.800000E-01    2.8285E-02       1        0.01
#      190    1.900000E-01    2.8169E-02       1        0.01
#      200    2.000000E-01    2.8088E-02       1        0.01
#      210    2.100000E-01    2.1938E-02       2        0.02
#      220    2.200000E-01    1.8353E-02       1        0.01
#      230    2.300000E-01    1.6353E-02       1        0.01
#      240    2.400000E-01    1.4971E-02       1        0.01
#      250    2.500000E-01    1.3796E-02       1        0.01
#      260    2.600000E-01    1.2867E-02       1        0.01
#      270    2.700000E-01    1.2189E-02       1        0.01
#      280    2.800000E-01    1.1749E-02       1        0.01
#      290    2.900000E-01    1.1530E-02       1        0.01
#      300    3.000000E-01    1.1512E-02       5        0.04
#      310    3.100000E-01    6.0989E-03       6        0.05
#      320    3.200000E-01    3.1275E-03       3        0.03
#      330    3.300000E-01    1.1685E-03       1        0.01
#      340    3.400000E-01    4.9339E-04       2        0.02
#      350    3.500000E-01    5.7286E-04       1        0.01
#      360    3.600000E-01    6.4015E-04       1        0.01
#      370    3.700000E-01    6.8503E-04       1        0.01
#      380    3.800000E-01    6.9259E-04       1        0.01
#      390    3.900000E-01    6.5030E-04       1        0.01
#      400    4.000000E-01    5.5567E-04       1        0.01
#      410    4.100000E-01    4.1949E-04       1        0.01
#      420    4.200000E-01    2.6284E-04       1        0.01
#      430    4.300000E-01    1.1262E-04       1        0.01
#      440    4.400000E-01    6.0470E-05       1        0.01
#      450    4.500000E-01    1.4699E-04       1        0.01
#      460    4.600000E-01    2.1247E-04       1        0.01
#      470    4.700000E-01    2.4807E-04       1        0.01
#      480    4.800000E-01    2.5927E-04       1        0.01
#      490    4.900000E-01    2.5258E-04       1        0.01
#      500    5.000000E-01    2.7860E-04       6        0.04
#      510    5.100000E-01    2.5840E-03       3        0.02
#      520    5.200000E-01    6.8212E-03       2        0.02
#      530    5.300000E-01    9.2318E-03       1        0.01
#      540    5.400000E-01    1.1190E-02       2        0.02
#      550    5.500000E-01    1.2391E-02       1        0.01
#      560    5.600000E-01    1.3349E-02       4        0.03
#      570    5.700000E-01    1.5595E-02       4        0.03
#      580    5.800000E-01    1.7570E-02       1        0.01
#      590    5.900000E-01    1.9149E-02       1        0.01
#      600    6.000000E-01    1.9474E-02       1        0.01
#      610    6.100000E-01    1.9477E-02       1        0.01
#      620    6.200000E-01    1.9438E-02       1        0.01
#      630    6.300000E-01    1.9347E-02       1        0.01
#      640    6.400000E-01    1.9210E-02       1        0.01
#      650    6.500000E-01    1.9038E-02       1        0.01
#      660    6.600000E-01    1.8845E-02       1        0.01
#      670    6.700000E-01    1.8647E-02       1        0.01
#      680    6.800000E-01    1.8458E-02       1        0.01
#      690    6.900000E-01    1.8286E-02       1        0.01
#     2960    2.960000E+00    1.4212E-02       1        0.01
#     2970    2.970000E+00    1.4826E-02       1        0.01
#     2980    2.980000E+00    1.5242E-02       1        0.01
#     2990    2.990000E+00    1.5471E-02       1        0.01
#     3000    3.000000E+00    1.5523E-02       1        0.01
#     3010    3.010000E+00    1.5416E-02       1        0.01
#     3020    3.020000E+00    1.5173E-02       1        0.01
#     3030    3.030000E+00    1.4826E-02       1        0.01
#     3040    3.040000E+00    1.4409E-02       1        0.01
#     3050    3.050000E+00    1.3960E-02       1        0.01
#     3060    3.060000E+00    1.3517E-02       1        0.01
#     3070    3.070000E+00    1.3114E-02       1        0.01
#     3080    3.080000E+00    1.2774E-02       1        0.01
#     3090    3.090000E+00    1.2514E-02       1        0.01
#     3100    3.100000E+00    1.2340E-02       1        0.02
#     3110    3.110000E+00    1.2251E-02       1        0.01
#     3120    3.120000E+00    1.2240E-02       1        0.01
#     3130    3.130000E+00    1.2294E-02       1        0.01
#     3140    3.140000E+00    1.2401E-02       1        0.01
#     3150    3.150000E+00    1.2547E-02       1        0.01
#     3160    3.160000E+00    1.2716E-02       1        0.01
#     3170    3.170000E+00    1.2896E-02       1        0.01
#     3180    3.180000E+00    1.3075E-02       1        0.01
#     3190    3.190000E+00    1.3241E-02       1        0.01
#     3200    3.200000E+00    1.3366E-02       6        0.05
#     3210    3.210000E+00    1.9083E-02       5        0.04
#     3220    3.220000E+00    2.2395E-02       1        0.01
#     3230    3.230000E+00    2.4565E-02       1        0.01
#     3240    3.240000E+00    2.5278E-02       1        0.01
#     3250    3.250000E+00    2.5615E-02       1        0.01
#     3260    3.260000E+00    2.5892E-02       1        0.01
#     3270    3.270000E+00    2.6099E-02       1        0.01
#     3280    3.280000E+00    2.6244E-02       1        0.01
#     3290    3.290000E+00    2.6342E-02       1        0.01
#     3300    3.300000E+00    2.6119E-02       8        0.06

# %%
_, Bc = tw_torus.compute_Bmat(cache_file='DATA_HODLR_B.save')
# Out:
#  Building block low rank magnetic field operator
#    Building hole and Vcoil columns
#    Building diagonal blocks
#      10%
#      20%
#      30%
#      40%
#      50%
#      60%
#      70%
#      80%
#      90%
#    Building off-diagonal blocks using ACA+
#      10%
#      20%
#      30%
#      40%
#      50%
#      60%
#      70%
#      80%
#      90%
#      Compression ratio:   8.1%  ( 1.00E+08/ 1.23E+09)
#      Time = 38s
#    Saving HODLR matrix from file: DATA_HODLR_B.save

# %%
# tw_torus.plot_td(nsteps,compute_B=True,sensor_obj=sensor_obj)
tw_torus.plot_td(nsteps,compute_B=True,plot_freq=30)
plot_data = tw_torus.build_XDMF()
# Out:
# Post-processing time-domain simulation
#
# Creating output files: oft_xdmf.XXXX.h5
#   Removing old Xdmf files
#     Removed 0 files
#   Found Group: thincurr
#     Found Mesh: icoils
#     Found Mesh: smesh

# %%
cam_position = [
    (-8, 8, 5),  # 相机位置坐标
    (0.0, 0.0, 0.0),  # 焦点坐标
    (0.0, 0.0, 1.0)  # 定义"向上"方向
]
windowsize = [1920, 1080]

pyvista.OFF_SCREEN = True  # 关键：启用离屏渲染
pyvista.start_xvfb()       # 启动虚拟显示（可选，部分场景需要）
pyvista.set_jupyter_backend('static') # Comment to enable interactive PyVista plots
# Out:
# /home/yfz/.conda/envs/OFT-260316/lib/python3.13/site-packages/pyvista/plotting/utilities/xvfb.py:48: PyVistaDeprecationWarning: This function is deprecated and will be removed in future version of PyVista. Use vtk-osmesa instead.
#   warnings.warn(

# %%
grid = plot_data['ThinCurr']['smesh'].get_pyvista_grid()
icoil_grid = plot_data['ThinCurr']['icoils'].get_pyvista_grid()
p = pyvista.Plotter(window_size=windowsize)
p.camera_position = cam_position
p.show_axes()
p.add_mesh(grid, color="white", opacity=0.25, show_edges=False)
p.add_mesh(grid, style="wireframe", color="black", opacity=1.0, show_edges=True, edge_opacity=1.0)
p.add_mesh(icoil_grid, color="blue", opacity=1.0, line_width=4)
# p.add_ruler(pointa=(0, -1.5, 0), pointb=(1.5, -1.5, 0), title='')
# p.add_box_axes()

p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
plot_step = 20
Jfull = plot_data['ThinCurr']['smesh'].get_field('J_v',timestep = plot_step)
Bfull = plot_data['ThinCurr']['smesh'].get_field('B_v',timestep = plot_step)
Ffull = np.zeros((np.shape(Jfull)))
print(np.shape(Ffull))
for i in range(np.shape(Jfull)[0]):
    Ffull[i,0] = Jfull[i,1] * Bfull[i,2] - Jfull[i,2] * Bfull[i,1]
    Ffull[i,1] = Jfull[i,2] * Bfull[i,0] - Jfull[i,0] * Bfull[i,2]
    Ffull[i,2] = Jfull[i,0] * Bfull[i,1] - Jfull[i,1] * Bfull[i,0] 

J_scale = 0.5 / 1e2
B_scale = 0.5 / 5e-4
F_scale = 0.25 / 2e-2
# Out:
# (20742, 3)

# %%
#
grid["vectors"] = Jfull
grid.set_active_vectors("vectors")
p = pyvista.Plotter(window_size=windowsize)
# scale = 0.25/(np.linalg.norm(Jfull,axis=1)).max()
# scale = 0.25/4e5
arrows = grid.glyph(scale="vectors", orient="vectors", factor=J_scale)
p.camera_position = cam_position
p.show_axes()
p.add_mesh(grid, color="white", opacity=0.25, show_edges=False)
# p.add_mesh(grid, style="wireframe", color="black", opacity=1.0, show_edges=True, edge_opacity=1.0)
p.add_mesh(arrows, cmap="turbo", scalar_bar_args={'title': "J", "vertical": True, "position_y":0.25, "position_x": 0.0})
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
#
grid["vectors"] = Bfull
grid.set_active_vectors("vectors")
p = pyvista.Plotter(window_size=windowsize)
# scale = 0.25/(np.linalg.norm(Bfull,axis=1)).max()
arrows = grid.glyph(scale="vectors", orient="vectors", factor=B_scale)
p.camera_position = cam_position
p.show_axes()
p.add_mesh(grid, color="white", opacity=0.25, show_edges=False)
# p.add_mesh(grid, style="wireframe", color="black", opacity=1.0, show_edges=True, edge_opacity=1.0)
p.add_mesh(arrows, cmap="turbo", scalar_bar_args={'title': "B", "vertical": True, "position_y":0.25, "position_x": 0.0})
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
print(np.shape(Jfull))
print(np.shape(Bfull))
# Out:
# (20742, 3)
# (20742, 3)

# %%
grid["vectors"] = Ffull
grid.set_active_vectors("vectors")
p = pyvista.Plotter(window_size=windowsize)
# scale = 0.25/(np.linalg.norm(Ffull,axis=1)).max()
arrows = grid.glyph(scale="vectors", orient="vectors", factor=F_scale)
p.camera_position = cam_position
p.show_axes()
p.add_mesh(grid, color="white", opacity=0.25, show_edges=False)
# p.add_mesh(grid, style="wireframe", color="black", opacity=1.0, show_edges=True, edge_opacity=1.0)
p.add_mesh(arrows, cmap="turbo", scalar_bar_args={'title': "F=J×B", "vertical": True, "position_y":0.25, "position_x": 0.0})
p.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
# --- 手动设置统一的标量范围 (User Requirement 2) ---
# 请根据你的实际物理量级修改这些值
J_clim = [0, 3e2]   # 例如：J 的范围 0 到 2 MA/m^2
B_clim = [0, 5e-4]     # 例如：B 的范围 0 到 3 T
F_clim = [0, 2e-2]   # 例如：F 的范围

colorbar_position_x = 0.01

fig_dir = "./figs"
os.makedirs(fig_dir, exist_ok=True)

# %%
# ==========================================
# 3. 循环绘制
# ==========================================
start_step = 0
end_step = 110
for plot_step in range(start_step, end_step + 1):
    print(f"正在处理时间步 {plot_step}/{end_step}...")

    # 获取数据
    try:
        Jfull = plot_data['ThinCurr']['smesh'].get_field('J_v', timestep=plot_step)
        Bfull = plot_data['ThinCurr']['smesh'].get_field('B_v', timestep=plot_step)
    except Exception as e:
        print(f"获取时间步 {plot_step} 的数据失败: {e}")
        continue

    # 1. 计算 F 向量 (F = J × B)
    Ffull = np.zeros_like(Jfull)
    Ffull[:, 0] = Jfull[:, 1] * Bfull[:, 2] - Jfull[:, 2] * Bfull[:, 1]
    Ffull[:, 1] = Jfull[:, 2] * Bfull[:, 0] - Jfull[:, 0] * Bfull[:, 2]
    Ffull[:, 2] = Jfull[:, 0] * Bfull[:, 1] - Jfull[:, 1] * Bfull[:, 0]

    # 2. [新增] 计算力的大小（模长）用于热力图
    F_mag = np.linalg.norm(Ffull, axis=1)
    J_norm = np.linalg.norm(Jfull, axis=1)

    current_time = plot_step * 1e-3 * 30

    # 创建 2x2 布局
    p = pyvista.Plotter(shape=(2, 2), window_size=windowsize, off_screen=True)

    # --- 子图 1 (0,0): J (保持矢量箭头) ---
    p.subplot(0, 0)
    grid["vectors"] = Jfull
    grid.set_active_vectors("vectors")
    arrows_J = grid.glyph(scale="vectors", orient="vectors", factor=J_scale)
    max_J = np.max(J_norm)
    p.add_mesh(grid, color="white", opacity=0.25, show_edges=False)
    p.add_mesh(arrows_J, cmap="turbo", clim=J_clim,
               scalar_bar_args={'title': "J(A/m^2)", "vertical": True, "n_labels": 5, "position_x": colorbar_position_x})
    p.add_text(f"Current Density J (Max: {max_J:.2e})\nt={current_time*1000:.2f} ms", font_size=10)
    p.camera_position = cam_position

    # --- 子图 2 (0,1): B (保持矢量箭头) ---
    p.subplot(0, 1)
    grid["vectors"] = Bfull
    grid.set_active_vectors("vectors")
    arrows_B = grid.glyph(scale="vectors", orient="vectors", factor=B_scale)
    p.add_mesh(grid, color="white", opacity=0.25, show_edges=False)
    p.add_mesh(arrows_B, cmap="turbo", clim=B_clim,
               scalar_bar_args={'title': "B(T)", "vertical": True, "n_labels": 5, "position_x": colorbar_position_x})
    p.add_text("Magnetic Field B", font_size=10)
    p.camera_position = cam_position

    # --- 子图 3 (1,0): F (修改为：力的大小热力图) ---
    p.subplot(1, 0)

    # 将计算好的模长赋值给网格
    grid["F_Magnitude"] = F_mag

    max_f = np.max(F_mag)
    print(f"  -> Time: {current_time*1000:.2f}ms, Max Force: {max_f:.4e}")

    # 直接绘制网格表面，使用 scalars 参数进行着色
    # cmap="magma" 或 "hot" 非常适合表示“力/能量”的大小
    # clim=F_clim 需要确保您在外部定义了 F_clim (例如 [0, max_force])，否则去掉该参数让其自动缩放
    p.add_mesh(grid, 
               scalars="F_Magnitude", 
               cmap="turbo",       # 改用 turbo，0值为深蓝，最大值为红
               clim=F_clim,        # 确保 F_clim 的范围与 print 出来的 Max Force 数量级匹配
               lighting=False,     # <--- 关键修改：关闭光照
               show_edges=False,   
               scalar_bar_args={'title': "F(N/m^2)", 
                                "vertical": True, 
                                "n_labels": 5, 
                                "position_x": colorbar_position_x,
                                "color": "black"} # 如果背景是白色的，字设为黑；背景黑则设为白
               )

    p.add_text(f"Lorentz force |F| (Max: {max_f:.2e})", font_size=10)
    p.camera_position = cam_position

    # # --- 子图 4 (1,1): 环面上的 B 三维矢量箭头 (替换掉不正确的输入波形图) ---
    # p.subplot(1, 1)
    # Btor = torus_B[plot_step, :, :]  # [npts,3]
    # torus_plot_mesh.point_data["B_vec"] = Btor[::torus_glyph_stride, :]
    # torus_plot_mesh.point_data["B_mag"] = np.linalg.norm(torus_plot_mesh.point_data["B_vec"], axis=1)

    # torus_plot_mesh.set_active_vectors("B_vec")
    # arrows_torus = torus_plot_mesh.glyph(
    #     orient="B_vec",
    #     scale="B_mag",
    #     factor=torus_B_scale,
    # )

    # # draw a faint torus surface for context
    # p.add_mesh(torus_mesh, color="white", opacity=0.15, show_edges=False)
    # p.add_mesh(
    #     arrows_torus,
    #     scalars="B_mag",
    #     cmap="turbo",
    #     clim=[0.0, Bmag_clim],
    #     lighting=False,
    #     scalar_bar_args={
    #         "title": "Torus |B| (T)",
    #         "vertical": True,
    #         "n_labels": 5,
    #         "position_x": colorbar_position_x,
    #         "color": "black",
    #     },
    # )
    # max_B = float(np.max(Bmag_all[plot_step, :]))
    # p.add_text(f"Torus B vectors (Max |B|: {max_B:.2e} T)\nt={current_time*1000:.2f} ms", font_size=10)
    # p.camera_position = cam_position

    # 保存图片
    filename = os.path.join(fig_dir, f"frame_{plot_step:04d}.png")
    p.screenshot(filename)
    p.close()

    print(f"已保存: {filename}")


print(f"所有图片已保存到 {fig_dir} 目录")
# Out:
# 正在处理时间步 0/110...
#   -> Time: 0.00ms, Max Force: 0.0000e+00
# 已保存: ./figs/frame_0000.png
# 正在处理时间步 1/110...
#   -> Time: 30.00ms, Max Force: 1.7713e-01
# 已保存: ./figs/frame_0001.png
# 正在处理时间步 2/110...
#   -> Time: 60.00ms, Max Force: 1.9936e-01
# 已保存: ./figs/frame_0002.png
# 正在处理时间步 3/110...
#   -> Time: 90.00ms, Max Force: 2.1224e-01
# 已保存: ./figs/frame_0003.png
# 正在处理时间步 4/110...
#   -> Time: 120.00ms, Max Force: 2.2166e-01
# 已保存: ./figs/frame_0004.png
# 正在处理时间步 5/110...
#   -> Time: 150.00ms, Max Force: 2.3642e-01
# 已保存: ./figs/frame_0005.png
# 正在处理时间步 6/110...
#   -> Time: 180.00ms, Max Force: 2.5047e-01
# 已保存: ./figs/frame_0006.png
# 正在处理时间步 7/110...
#   -> Time: 210.00ms, Max Force: 1.3308e-01
# 已保存: ./figs/frame_0007.png
# 正在处理时间步 8/110...
#   -> Time: 240.00ms, Max Force: 1.2213e-01
# 已保存: ./figs/frame_0008.png
# 正在处理时间步 9/110...
#   -> Time: 270.00ms, Max Force: 1.2596e-01
# 已保存: ./figs/frame_0009.png
# 正在处理时间步 10/110...
#   -> Time: 300.00ms, Max Force: 1.2611e-01
# 已保存: ./figs/frame_0010.png
# 正在处理时间步 11/110...
#   -> Time: 330.00ms, Max Force: 9.7591e-03
# 已保存: ./figs/frame_0011.png
# 正在处理时间步 12/110...
#   -> Time: 360.00ms, Max Force: 6.5599e-03
# 已保存: ./figs/frame_0012.png
# 正在处理时间步 13/110...
#   -> Time: 390.00ms, Max Force: 2.2832e-03
# 已保存: ./figs/frame_0013.png
# 正在处理时间步 14/110...
#   -> Time: 420.00ms, Max Force: 1.4471e-03
# 已保存: ./figs/frame_0014.png
# 正在处理时间步 15/110...
#   -> Time: 450.00ms, Max Force: 5.5417e-04
# 已保存: ./figs/frame_0015.png
# 正在处理时间步 16/110...
#   -> Time: 480.00ms, Max Force: 8.8896e-04
# 已保存: ./figs/frame_0016.png
# 正在处理时间步 17/110...
#   -> Time: 510.00ms, Max Force: 4.7927e-02
# 已保存: ./figs/frame_0017.png
# 正在处理时间步 18/110...
#   -> Time: 540.00ms, Max Force: 9.8508e-02
# 已保存: ./figs/frame_0018.png
# 正在处理时间步 19/110...
#   -> Time: 570.00ms, Max Force: 1.3339e-01
# 已保存: ./figs/frame_0019.png
# 正在处理时间步 20/110...
#   -> Time: 600.00ms, Max Force: 1.2446e-01
# 已保存: ./figs/frame_0020.png
# 正在处理时间步 21/110...
#   -> Time: 630.00ms, Max Force: 1.0522e-01
# 已保存: ./figs/frame_0021.png
# 正在处理时间步 22/110...
#   -> Time: 660.00ms, Max Force: 9.0040e-02
# 已保存: ./figs/frame_0022.png
# 正在处理时间步 23/110...
#   -> Time: 690.00ms, Max Force: 7.7007e-02
# 已保存: ./figs/frame_0023.png
# 正在处理时间步 24/110...
#   -> Time: 720.00ms, Max Force: 6.4210e-02
# 已保存: ./figs/frame_0024.png
# 正在处理时间步 25/110...
#   -> Time: 750.00ms, Max Force: 5.3371e-02
# 已保存: ./figs/frame_0025.png
# 正在处理时间步 26/110...
#   -> Time: 780.00ms, Max Force: 4.3151e-02
# 已保存: ./figs/frame_0026.png
# 正在处理时间步 27/110...
#   -> Time: 810.00ms, Max Force: 2.5813e-02
# 已保存: ./figs/frame_0027.png
# 正在处理时间步 28/110...
#   -> Time: 840.00ms, Max Force: 1.9667e-02
# 已保存: ./figs/frame_0028.png
# 正在处理时间步 29/110...
#   -> Time: 870.00ms, Max Force: 1.9798e-02
# 已保存: ./figs/frame_0029.png
# 正在处理时间步 30/110...
#   -> Time: 900.00ms, Max Force: 2.3037e-02
# 已保存: ./figs/frame_0030.png
# 正在处理时间步 31/110...
#   -> Time: 930.00ms, Max Force: 2.7201e-02
# 已保存: ./figs/frame_0031.png
# 正在处理时间步 32/110...
#   -> Time: 960.00ms, Max Force: 3.0098e-02
# 已保存: ./figs/frame_0032.png
# 正在处理时间步 33/110...
#   -> Time: 990.00ms, Max Force: 3.1136e-02
# 已保存: ./figs/frame_0033.png
# 正在处理时间步 34/110...
#   -> Time: 1020.00ms, Max Force: 3.1397e-02
# 已保存: ./figs/frame_0034.png
# 正在处理时间步 35/110...
#   -> Time: 1050.00ms, Max Force: 3.1815e-02
# 已保存: ./figs/frame_0035.png
# 正在处理时间步 36/110...
#   -> Time: 1080.00ms, Max Force: 1.6055e-02
# 已保存: ./figs/frame_0036.png
# 正在处理时间步 37/110...
#   -> Time: 1110.00ms, Max Force: 1.4924e-02
# 已保存: ./figs/frame_0037.png
# 正在处理时间步 38/110...
#   -> Time: 1140.00ms, Max Force: 1.5518e-02
# 已保存: ./figs/frame_0038.png
# 正在处理时间步 39/110...
#   -> Time: 1170.00ms, Max Force: 1.9137e-02
# 已保存: ./figs/frame_0039.png
# 正在处理时间步 40/110...
#   -> Time: 1200.00ms, Max Force: 2.3260e-02
# 已保存: ./figs/frame_0040.png
# 正在处理时间步 41/110...
#   -> Time: 1230.00ms, Max Force: 1.1604e-02
# 已保存: ./figs/frame_0041.png
# 正在处理时间步 42/110...
#   -> Time: 1260.00ms, Max Force: 8.8959e-03
# 已保存: ./figs/frame_0042.png
# 正在处理时间步 43/110...
#   -> Time: 1290.00ms, Max Force: 1.0943e-02
# 已保存: ./figs/frame_0043.png
# 正在处理时间步 44/110...
#   -> Time: 1320.00ms, Max Force: 1.2903e-02
# 已保存: ./figs/frame_0044.png
# 正在处理时间步 45/110...
#   -> Time: 1350.00ms, Max Force: 1.3931e-02
# 已保存: ./figs/frame_0045.png
# 正在处理时间步 46/110...
#   -> Time: 1380.00ms, Max Force: 1.4616e-02
# 已保存: ./figs/frame_0046.png
# 正在处理时间步 47/110...
#   -> Time: 1410.00ms, Max Force: 1.4991e-02
# 已保存: ./figs/frame_0047.png
# 正在处理时间步 48/110...
#   -> Time: 1440.00ms, Max Force: 1.5023e-02
# 已保存: ./figs/frame_0048.png
# 正在处理时间步 49/110...
#   -> Time: 1470.00ms, Max Force: 1.5095e-02
# 已保存: ./figs/frame_0049.png
# 正在处理时间步 50/110...
#   -> Time: 1500.00ms, Max Force: 1.5496e-02
# 已保存: ./figs/frame_0050.png
# 正在处理时间步 51/110...
#   -> Time: 1530.00ms, Max Force: 1.6156e-02
# 已保存: ./figs/frame_0051.png
# 正在处理时间步 52/110...
#   -> Time: 1560.00ms, Max Force: 1.6888e-02
# 已保存: ./figs/frame_0052.png
# 正在处理时间步 53/110...
#   -> Time: 1590.00ms, Max Force: 1.7573e-02
# 已保存: ./figs/frame_0053.png
# 正在处理时间步 54/110...
#   -> Time: 1620.00ms, Max Force: 1.8159e-02
# 已保存: ./figs/frame_0054.png
# 正在处理时间步 55/110...
#   -> Time: 1650.00ms, Max Force: 1.8647e-02
# 已保存: ./figs/frame_0055.png
# 正在处理时间步 56/110...
#   -> Time: 1680.00ms, Max Force: 1.9087e-02
# 已保存: ./figs/frame_0056.png
# 正在处理时间步 57/110...
#   -> Time: 1710.00ms, Max Force: 1.9539e-02
# 已保存: ./figs/frame_0057.png
# 正在处理时间步 58/110...
#   -> Time: 1740.00ms, Max Force: 2.0036e-02
# 已保存: ./figs/frame_0058.png
# 正在处理时间步 59/110...
#   -> Time: 1770.00ms, Max Force: 2.0574e-02
# 已保存: ./figs/frame_0059.png
# 正在处理时间步 60/110...
#   -> Time: 1800.00ms, Max Force: 2.1131e-02
# 已保存: ./figs/frame_0060.png
# 正在处理时间步 61/110...
#   -> Time: 1830.00ms, Max Force: 2.1685e-02
# 已保存: ./figs/frame_0061.png
# 正在处理时间步 62/110...
#   -> Time: 1860.00ms, Max Force: 2.2223e-02
# 已保存: ./figs/frame_0062.png
# 正在处理时间步 63/110...
#   -> Time: 1890.00ms, Max Force: 2.2744e-02
# 已保存: ./figs/frame_0063.png
# 正在处理时间步 64/110...
#   -> Time: 1920.00ms, Max Force: 2.3256e-02
# 已保存: ./figs/frame_0064.png
# 正在处理时间步 65/110...
#   -> Time: 1950.00ms, Max Force: 2.3768e-02
# 已保存: ./figs/frame_0065.png
# 正在处理时间步 66/110...
#   -> Time: 1980.00ms, Max Force: 2.4287e-02
# 已保存: ./figs/frame_0066.png
# 正在处理时间步 67/110...
#   -> Time: 2010.00ms, Max Force: 2.4813e-02
# 已保存: ./figs/frame_0067.png
# 正在处理时间步 68/110...
#   -> Time: 2040.00ms, Max Force: 2.5342e-02
# 已保存: ./figs/frame_0068.png
# 正在处理时间步 69/110...
#   -> Time: 2070.00ms, Max Force: 2.5872e-02
# 已保存: ./figs/frame_0069.png
# 正在处理时间步 70/110...
#   -> Time: 2100.00ms, Max Force: 2.6399e-02
# 已保存: ./figs/frame_0070.png
# 正在处理时间步 71/110...
#   -> Time: 2130.00ms, Max Force: 2.6924e-02
# 已保存: ./figs/frame_0071.png
# 正在处理时间步 72/110...
#   -> Time: 2160.00ms, Max Force: 2.7447e-02
# 已保存: ./figs/frame_0072.png
# 正在处理时间步 73/110...
#   -> Time: 2190.00ms, Max Force: 2.7969e-02
# 已保存: ./figs/frame_0073.png
# 正在处理时间步 74/110...
#   -> Time: 2220.00ms, Max Force: 2.8493e-02
# 已保存: ./figs/frame_0074.png
# 正在处理时间步 75/110...
#   -> Time: 2250.00ms, Max Force: 2.9018e-02
# 已保存: ./figs/frame_0075.png
# 正在处理时间步 76/110...
#   -> Time: 2280.00ms, Max Force: 2.9543e-02
# 已保存: ./figs/frame_0076.png
# 正在处理时间步 77/110...
#   -> Time: 2310.00ms, Max Force: 3.0068e-02
# 已保存: ./figs/frame_0077.png
# 正在处理时间步 78/110...
#   -> Time: 2340.00ms, Max Force: 3.0594e-02
# 已保存: ./figs/frame_0078.png
# 正在处理时间步 79/110...
#   -> Time: 2370.00ms, Max Force: 3.1118e-02
# 已保存: ./figs/frame_0079.png
# 正在处理时间步 80/110...
#   -> Time: 2400.00ms, Max Force: 3.1643e-02
# 已保存: ./figs/frame_0080.png
# 正在处理时间步 81/110...
#   -> Time: 2430.00ms, Max Force: 3.2167e-02
# 已保存: ./figs/frame_0081.png
# 正在处理时间步 82/110...
#   -> Time: 2460.00ms, Max Force: 3.2692e-02
# 已保存: ./figs/frame_0082.png
# 正在处理时间步 83/110...
#   -> Time: 2490.00ms, Max Force: 3.3216e-02
# 已保存: ./figs/frame_0083.png
# 正在处理时间步 84/110...
#   -> Time: 2520.00ms, Max Force: 8.1367e-03
# 已保存: ./figs/frame_0084.png
# 正在处理时间步 85/110...
#   -> Time: 2550.00ms, Max Force: 6.2818e-03
# 已保存: ./figs/frame_0085.png
# 正在处理时间步 86/110...
#   -> Time: 2580.00ms, Max Force: 6.4026e-03
# 已保存: ./figs/frame_0086.png
# 正在处理时间步 87/110...
#   -> Time: 2610.00ms, Max Force: 5.6941e-03
# 已保存: ./figs/frame_0087.png
# 正在处理时间步 88/110...
#   -> Time: 2640.00ms, Max Force: 8.2142e-03
# 已保存: ./figs/frame_0088.png
# 正在处理时间步 89/110...
#   -> Time: 2670.00ms, Max Force: 1.0148e-02
# 已保存: ./figs/frame_0089.png
# 正在处理时间步 90/110...
#   -> Time: 2700.00ms, Max Force: 9.3025e-03
# 已保存: ./figs/frame_0090.png
# 正在处理时间步 91/110...
#   -> Time: 2730.00ms, Max Force: 2.6394e-02
# 已保存: ./figs/frame_0091.png
# 正在处理时间步 92/110...
#   -> Time: 2760.00ms, Max Force: 3.1205e-02
# 已保存: ./figs/frame_0092.png
# 正在处理时间步 93/110...
#   -> Time: 2790.00ms, Max Force: 2.7007e-02
# 已保存: ./figs/frame_0093.png
# 正在处理时间步 94/110...
#   -> Time: 2820.00ms, Max Force: 2.7421e-02
# 已保存: ./figs/frame_0094.png
# 正在处理时间步 95/110...
#   -> Time: 2850.00ms, Max Force: 2.7811e-02
# 已保存: ./figs/frame_0095.png
# 正在处理时间步 96/110...
#   -> Time: 2880.00ms, Max Force: 2.7253e-02
# 已保存: ./figs/frame_0096.png
# 正在处理时间步 97/110...
#   -> Time: 2910.00ms, Max Force: 9.1669e-02
# 已保存: ./figs/frame_0097.png
# 正在处理时间步 98/110...
#   -> Time: 2940.00ms, Max Force: 8.7347e-02
# 已保存: ./figs/frame_0098.png
# 正在处理时间步 99/110...
#   -> Time: 2970.00ms, Max Force: 8.9053e-02
# 已保存: ./figs/frame_0099.png
# 正在处理时间步 100/110...
#   -> Time: 3000.00ms, Max Force: 8.5038e-02
# 已保存: ./figs/frame_0100.png
# 正在处理时间步 101/110...
#   -> Time: 3030.00ms, Max Force: 7.4017e-02
# 已保存: ./figs/frame_0101.png
# 正在处理时间步 102/110...
#   -> Time: 3060.00ms, Max Force: 6.4772e-02
# 已保存: ./figs/frame_0102.png
# 正在处理时间步 103/110...
#   -> Time: 3090.00ms, Max Force: 5.8252e-02
# 已保存: ./figs/frame_0103.png
# 正在处理时间步 104/110...
#   -> Time: 3120.00ms, Max Force: 5.2241e-02
# 已保存: ./figs/frame_0104.png
# 正在处理时间步 105/110...
#   -> Time: 3150.00ms, Max Force: 4.6105e-02
# 已保存: ./figs/frame_0105.png
# 正在处理时间步 106/110...
#   -> Time: 3180.00ms, Max Force: 3.9815e-02
# 已保存: ./figs/frame_0106.png
# 正在处理时间步 107/110...
#   -> Time: 3210.00ms, Max Force: 8.0922e-02
# 已保存: ./figs/frame_0107.png
# 正在处理时间步 108/110...
#   -> Time: 3240.00ms, Max Force: 1.1281e-01
# 已保存: ./figs/frame_0108.png
# 正在处理时间步 109/110...
#   -> Time: 3270.00ms, Max Force: 1.1859e-01
# 已保存: ./figs/frame_0109.png
# 正在处理时间步 110/110...
#   -> Time: 3300.00ms, Max Force: 1.2127e-01
# 已保存: ./figs/frame_0110.png
# 所有图片已保存到 ./figs 目录

# %%
import subprocess

# 使用ffmpeg将图片编码为视频
print("\n正在使用ffmpeg生成视频...")
# 创建保存视频的目录
video_dir = "./anime"
os.makedirs(video_dir, exist_ok=True)
# 视频文件名
video_path = os.path.join(video_dir, "simulation.mp4")
# ffmpeg命令
# -r 30: 设置帧率为30fps
# -i: 输入文件模式
# -c:v libx264: 使用H.264编码
# -pix_fmt yuv420p: 确保兼容性
# -vf "fps=30": 确保输出帧率
ffmpeg_cmd = [
    'ffmpeg',
    '-y',  # 覆盖输出文件而不询问
    '-framerate', '10',  # 输入帧率
    '-i', os.path.join(fig_dir, 'frame_%04d.png'),  # 输入文件模式
    '-c:v', 'libx264',  # 视频编码器
    '-pix_fmt', 'yuv420p',  # 像素格式
    '-vf', 'fps=30',  # 输出帧率
    '-crf', '18',  # 质量参数（0-51，值越小质量越高）
    '-preset', 'slow',  # 编码速度预设
    video_path
]
try:
    # 执行ffmpeg命令
    print("执行命令:", ' '.join(ffmpeg_cmd))
    result = subprocess.run(ffmpeg_cmd, capture_output=True, text=True, check=True)
    print("视频生成成功!")
    print(f"视频已保存到: {video_path}")

    # 如果需要，可以添加更多视频编码选项
    # 例如，生成GIF动画：
    # gif_path = os.path.join(video_dir, "simulation.gif")
    # gif_cmd = [
    #     'ffmpeg',
    #     '-y',
    #     '-framerate', '30',
    #     '-i', os.path.join(fig_dir, 'frame_%04d.png'),
    #     '-vf', 'fps=15,scale=960:-1:flags=lanczos',
    #     '-c:v', 'gif',
    #     gif_path
    # ]
    # subprocess.run(gif_cmd, check=True)
    # print(f"GIF动画已保存到: {gif_path}")

except subprocess.CalledProcessError as e:
    print(f"ffmpeg执行失败: {e}")
    print(f"标准错误输出:\n{e.stderr}")
# Out:
# 正在使用ffmpeg生成视频...
# 执行命令: ffmpeg -y -framerate 10 -i ./figs/frame_%04d.png -c:v libx264 -pix_fmt yuv420p -vf fps=30 -crf 18 -preset slow ./anime/simulation.mp4
# 视频生成成功!
# 视频已保存到: ./anime/simulation.mp4
